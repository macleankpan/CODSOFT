# %% [markdown]
# Importation of all needed libraries  for data manipulating, analysis and visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns
import scipy.stats as st

# %% [markdown]
# ### DATA ANALYSIS

# %%
read_data = pd.read_csv("IRIS.csv")

# %%
read_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#getting the top and bottom 10 data from the dataset provided
read_data.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa

# %%
#getting bottom 20 data from the dataset
read_data.tail(10)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 140           6.7          3.1           5.6          2.4  Iris-virginica
# 141           6.9          3.1           5.1          2.3  Iris-virginica
# 142           5.8          2.7           5.1          1.9  Iris-virginica
# 143           6.8          3.2           5.9          2.3  Iris-virginica
# 144           6.7          3.3           5.7          2.5  Iris-virginica
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
read_data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
read_data.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
read_data.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
read_data.nunique
# Out:
# <bound method DataFrame.nunique of      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]>

# %% [markdown]
# ### DATA VISUALIZATION

# %%
sns.scatterplot( x=read_data[ "sepal_length"], y=read_data["sepal_width"])
plt.show()

# %%
sns.scatterplot( x=read_data[ "petal_length"], y=read_data["petal_width"], hue=read_data[ "species"] )
plt.show()

# %% [markdown]
# For the scatter plots shown above, three clusters can be observed from the petal side

# %% [markdown]
# plotting graph using seaborn library

# %%
sns.pointplot(x=read_data["sepal_length"], y=read_data['petal_length'])
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.lineplot(x=read_data["sepal_length"], y=read_data['petal_length'])
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.barplot(x=read_data["sepal_length"], y=read_data['petal_length'])
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %% [markdown]
# Relationship between sepal length and petal length

# %%
sns.scatterplot(x=read_data['sepal_length'], y=read_data[ 'petal_length'])
plt.title('Relationship between sepal length and petal length')
# Out:
# Text(0.5, 1.0, 'Relationship between sepal length and petal length')

# %%
plt.plot(read_data["sepal_length"])
plt.plot(read_data["petal_length"])
plt.legend(["SEPAL LENGTH", "PETAL LENGTH"])
plt.title("Relationship between sepal length and petal length")
# Out:
# Text(0.5, 1.0, 'Relationship between sepal length and petal length')

# %% [markdown]
# Relationship between sepal width and petal width

# %%
sns.scatterplot(x=read_data['sepal_width'], y=read_data[ 'petal_width'])
plt.title('Relationship between sepal width and petal width')
# Out:
# Text(0.5, 1.0, 'Relationship between sepal width and petal width')

# %%
plt.plot(read_data["sepal_width"])
plt.plot(read_data["petal_width"])
plt.legend(["SEPAL WIDTH", "PETAL WIDTH"])
plt.title("Relationship between sepal width and petal width")
# Out:
# Text(0.5, 1.0, 'Relationship between sepal width and petal width')

# %% [markdown]
# Plotting a combination of all columns

# %%
plt.plot(read_data["sepal_width"])
plt.plot(read_data["petal_width"])
plt.plot(read_data["sepal_length"])
plt.plot(read_data["petal_length"])
plt.legend(["SEPAL WIDTH", "PETAL WIDTH", "SEPAL LENGTH", "PETAL LENGTH"] )

# %% [markdown]
# Now, let's create a plot for all species present in the dataset provided

# %%
sns.lmplot(x='sepal_length', y='sepal_width', data=read_data, hue="species", legend=False)

plt.legend(['sepal width', 'sepal length'])

# %% [markdown]
# Histogram Plot

# %%
fig, axes = plt.subplots(1, 4, figsize=(20, 5))

# Plot histogram for 'sepal_length'
read_data['sepal_length'].hist(ax=axes[0], color='b')
axes[0].set_title('SEPAL LENGTH')

# Plot histogram for 'sepal_width'
read_data['sepal_width'].hist(ax=axes[1], color='r')
axes[1].set_title('SEPAL WIDTH')

# Plot histogram for 'petal_length'
read_data['petal_length'].hist(ax=axes[2], color='g')
axes[2].set_title('PETAL LENGTH')

# Plot histogram for 'petal_width'
read_data['petal_width'].hist(ax=axes[3], color='r')
axes[3].set_title('PETAL WIDTH')

plt.show()

# %% [markdown]
# Comparing the feature of each species

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

# Plot histogram for 'sepal_length'
sns.histplot(data=read_data, x='sepal_length', hue='species', kde=True, ax=axes[0, 0])
axes[0, 0].set_title('Sepal Length by Species')

# Plot histogram for 'sepal_width'
sns.histplot(data=read_data, x='sepal_width', hue='species', kde=True, ax=axes[0, 1])
axes[0, 1].set_title('Sepal Width by Species')

# Plot histogram for 'petal_length'
sns.histplot(data=read_data, x='petal_length', hue='species', kde=True, ax=axes[1, 0])
axes[1, 0].set_title('Petal Length by Species')

# Plot histogram for 'petal_width'
sns.histplot(data=read_data, x='petal_width', hue='species', kde=True, ax=axes[1, 1])
axes[1, 1].set_title('Petal Width by Species')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

# Plot bar plot for 'sepal_length'
sns.barplot(x='species', y='sepal_length', data=read_data, ax=axes[0, 0])
axes[0, 0].set_title('Sepal Length by Species')

# Plot bar plot for 'sepal_width'
sns.barplot(x='species', y='sepal_width', data=read_data, ax=axes[0, 1])
axes[0, 1].set_title('Sepal Width by Species')

# Plot bar plot for 'petal_length'
sns.barplot(x='species', y='petal_length', data=read_data, ax=axes[1, 0])
axes[1, 0].set_title('Petal Length by Species')

# Plot bar plot for 'petal_width'
sns.barplot(x='species', y='petal_width', data=read_data, ax=axes[1, 1])
axes[1, 1].set_title('Petal Width by Species')

plt.tight_layout()
plt.show()

# %% [markdown]
# Conclusions drawn from the above analysis (bavariate)
# - iris-setosa has the shorter petal length and iris virginica has longer
# - iris setosa has the shorter sepal length and iris virginica has longer
# - iris setosa has a longer sepal width than iris virginica
# - iris setosa has a shorter petal width whiles iris virginica has a longer one

# %% [markdown]
# distribution of species in the dataset using a piechart to show the percentage distribution

# %%
read_data['species'].value_counts().plot.pie(
    explode=[0.04, 0.04, 0.04],
    
    autopct = '%1.2f%%',
    colors=["lightcoral", "lightblue", "lightgreen"]
).set_title('SPECIES CLASSIFICATION (IRIS)')

plt.ylabel('')  # This removes the 'species' label from the y-axis for a cleaner look
plt.show()

# %% [markdown]
# Correlation of Data

# %%
# Select only the numeric columns
numeric_data = read_data.select_dtypes(include=[float, int])

correlation =numeric_data.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation, annot=True, cmap='coolwarm', center=0)
plt.show()

# %% [markdown]
# Cleaning duplicate data in the dataset

# %%
read_data[read_data.duplicated()]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 34            4.9          3.1           1.5          0.1     Iris-setosa
# 37            4.9          3.1           1.5          0.1     Iris-setosa
# 142           5.8          2.7           5.1          1.9  Iris-virginica

# %%
read_data.drop_duplicates(inplace=True)

# %%
read_data.shape
# Out:
# (147, 5)

# %% [markdown]
# ### MACHINE LEARNING MODEL IMPLEMENTATION

# %% [markdown]
# Import libraries for Machine learning

# %%
from sklearn import preprocessing, linear_model
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# Label Encoder

# %%
label_encoder = preprocessing.LabelEncoder()
read_data['species']= label_encoder.fit_transform(read_data['species'])

read_data['species'].unique()
# Out:
# array([0, 1, 2])

# %% [markdown]
# From the output above, the value of this species have been converted to an array,
# - Iris-setosa = 0
# - iris-versicolor = 1
# - iris-virginica = 2

# %%
#to check if the values of species were converted to numeric form or not
read_data['species'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: species, dtype: int32

# %% [markdown]
# Splitting the data into sets

# %%
x= read_data.drop(['species'], axis=1)  #independent variable

y= read_data['species']                 #dependent variable

# %% [markdown]
# Declaring ration for traning and testing

# %%
x_sepal_train, x_sepal_test, y_species_train, y_species_test = train_test_split(x,y, random_state=0, test_size=30/100)

# %%
x_sepal_train.shape, x_sepal_test.shape, y_species_train.shape, y_species_test.shape
# Out:
# ((102, 4), (45, 4), (102,), (45,))

# %%
x_sepal_train
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 140           6.7          3.1           5.6          2.4
# 116           6.5          3.0           5.5          1.8
# 99            5.7          2.8           4.1          1.3
# 96            5.7          2.9           4.2          1.3
# 62            6.0          2.2           4.0          1.0
# ..            ...          ...           ...          ...
# 9             4.9          3.1           1.5          0.1
# 105           7.6          3.0           6.6          2.1
# 69            5.6          2.5           3.9          1.1
# 119           6.0          2.2           5.0          1.5
# 49            5.0          3.3           1.4          0.2
#
# [102 rows x 4 columns]

# %%
x_sepal_test
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 7             5.0          3.4           1.5          0.2
# 24            4.8          3.4           1.9          0.2
# 27            5.2          3.5           1.5          0.2
# 122           7.7          2.8           6.7          2.0
# 146           6.3          2.5           5.0          1.9
# 53            5.5          2.3           4.0          1.3
# 45            4.8          3.0           1.4          0.3
# 22            4.6          3.6           1.0          0.2
# 114           5.8          2.8           5.1          2.4
# 26            5.0          3.4           1.6          0.4
# 42            4.4          3.2           1.3          0.2
# 80            5.5          2.4           3.8          1.1
# 133           6.3          2.8           5.1          1.5
# 64            5.6          2.9           3.6          1.3
# 73            6.1          2.8           4.7          1.2
# ...

# %%
y_species_train
# Out:
# 140    2
# 116    2
# 99     1
# 96     1
# 62     1
#       ..
# 9      0
# 105    2
# 69     1
# 119    2
# 49     0
# Name: species, Length: 102, dtype: int32

# %%
y_species_test
# Out:
# 7      0
# 24     0
# 27     0
# 122    2
# 146    2
# 53     1
# 45     0
# 22     0
# 114    2
# 26     0
# 42     0
# 80     1
# 133    2
# 64     1
# 73     1
# 93     1
# 16     0
# 56     1
# 100    2
# 8      0
# 91     1
# 39     0
# 148    2
# 86     1
# 120    2
# 33     0
# 147    2
# 92     1
# 85     1
# 107    2
# 78     1
# 18     0
# 47     0
# 52     1
# 46     0
# 2      0
# 65     1
# 10     0
# 134    2
# 109    2
# 61     1
# 112    2
# 63     1
# 75     1
# 125    2
# Name: species, dtype: int32

# %% [markdown]
# Linear Regression (Supervised Learning)
# - It will be used to show the linear relationship between y(dependent variable) and x(independent variable)

# %%
model=LinearRegression()

# %%
#input data into the machine

model.fit(x_sepal_train, y_species_train)
y_species_predict = model.predict(x_sepal_test)

# %% [markdown]
# Check the accuracy of the linear regression model

# %%
score = model.score(x_sepal_test, y_species_test)
score = round(score * 100, 4)

print("Accuracy of model = ", str(score), " percent.")
# Out:
# Accuracy of model =  92.4354  percent.

# %%
logistic_model = linear_model.LogisticRegression(max_iter=130)
logistic_model.fit(x_sepal_train, y_species_train)
# Out:
# LogisticRegression(max_iter=130)

# %%
y_species_logistic_predict =logistic_model.predict(x_sepal_test)

# %%
score_lg = logistic_model.score(x_sepal_test, y_species_test)
score_lg = round(score_lg * 100, 4)

print("Accuracy of model = ", str(score_lg), " percent.")
# Out:
# Accuracy of model =  100.0  percent.

# %%
cm = confusion_matrix(y_species_test, y_species_test)
cm
# Out:
# array([[16,  0,  0],
#        [ 0, 16,  0],
#        [ 0,  0, 13]], dtype=int64)

# %% [markdown]
# Plotting Confusion matrix using a heatmap

# %%
sns.heatmap(cm, annot=True, cmap = "coolwarm")
plt.rcParams['figure.figsize']= (10,2)
plt.xlabel('PREDICTED VALUE')
plt.ylabel('SPECIES')
# Out:
# Text(50.722222222222214, 0.5, 'SPECIES')

# %% [markdown]
# K-Nearest Neighbour MODEL

# %%
knnModel = KNeighborsClassifier(n_neighbors=3)  #instantiate learning model (k =3)
knnModel.fit(x_sepal_train, y_species_train)
y_knn_pred = knnModel.predict(x_sepal_test)

# %% [markdown]
# Checking the Accuracy

# %%
accuracy= accuracy_score(y_species_test, y_knn_pred)*100
accuracy
# Out:
# 95.55555555555556

# %%
print(classification_report(y_species_test, y_knn_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       0.94      0.94      0.94        16
#            2       0.92      0.92      0.92        13
#
#     accuracy                           0.96        45
#    macro avg       0.95      0.95      0.95        45
# weighted avg       0.96      0.96      0.96        45

# %%
knn_cm = confusion_matrix(y_species_test, y_knn_pred)
knn_cm
# Out:
# array([[16,  0,  0],
#        [ 0, 15,  1],
#        [ 0,  1, 12]], dtype=int64)

# %%
sns.heatmap(knn_cm, annot=True, cmap = "coolwarm")
plt.rcParams['figure.figsize']= (10,2)
plt.xlabel('PREDICTED VALUE')
plt.ylabel('SPECIES')
# Out:
# Text(95.72222222222221, 0.5, 'SPECIES')

# %% [markdown]
# CHOOSING BEST MODEL FOR CLASSIFICATION

# %%
scores_plt = [score, score_lg, accuracy]
algorithm = ['Linear Regression', 'Logistic Regression', "kNN"]
sns.set(rc={"figure.figsize": (11,6)})
plt.xlabel('Algorithms')
plt.ylabel(" Accuracy")

sns.barplot(x=algorithm, y=scores_plt)
plt.show()

# %%
X_new =np.array([[4.6,3.4, 1.4,0.3]])

prediction = logistic_model.predict(X_new)
print("Species Prediction: {}".format(prediction))
# Out:
# Species Prediction: [0]
# C:\Users\ZBOOK\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
